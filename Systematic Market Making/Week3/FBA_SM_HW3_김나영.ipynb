# %% [markdown]
# # [HW3] FBA QUANT - SYSTEMATIC MARKET MAKING

# %% [markdown]
# Kim Na Young (dudskrla09@gmail.com)

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 1. Foundations of Reinforcement Learning with Applications in Finance

# %% [markdown]
# Please run the Python codes in Chapter 4. Markov Decision Processes.

# %% [markdown]
# ### Solution 1.

# %% [markdown]
# https://github.com/TikhonJelvis/RL-book/tree/master/rl/chapter4

# %% [markdown]
# ----

# %% [markdown]
# ### Problem 2. Recycling Robot

# %% [markdown]
# Consider the recycling robot. Say at an arbitrary time step t, the state of the robot's battery is high ($ S_t=high $). Then, in response, the agent decides to search ($ A_t  = search $). You learned in the previous concept that in this case, the environment responds to the agent by flipping a theoretical coin with 70% probability of landing heads.
#
# - If the coin lands head, the environment decides that the next state is high ($ S_{t+1}=high $), and the reward is 4 ($ R_{t+1}=4 $).
#
# - If the coin lands tail, the environment decides that the next state is high ($ S_{t+1}=low $), and the reward is 4 ($ R_{t+1}=4 $).
#
# We can completely define how the environment decides the state and reward by specifying
#
# $$ p(s^{\\'},r∣s,a)≐P(S_{t+1}=s^{\\'},R_{t+1}=r∣S_t=s,A_t=a) $$
#
# for each possible $ s^{\\'}, r, s, $ and $ a $.
#
# What are $ p(high ,-3∣low,search) $ and $ p(high,-3 | high,recharge) $?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Solution 2.

# %% [markdown]
# - (1) $ p(high ,-3∣low,search) =  p(S_{t+1} = high, R_{t+1} = -3 | S_t = low, A_t = search)  = 0.8 $
#
# - (2) $ p(high,-3 | high,recharge) =  p(S_{t+1} = high, R_{t+1} = -3 | S_t = high, A_t = recharge) = 0 $
#
#     (∵ High state doesn't has Recharge action)

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 3. Grid World

# %% [markdown]
# Each of the nine states in the MDP is labeled as one of $ S^+=\{s_1,s_2,…,s_9 \} $ , where $ s_9 $ is a terminal state. Consider the (deterministic) policy that is indicated (in orange) in the figure below.
# Calculate the state-value function $ v_π (s_4 ) $ and $ v_π (s_1 ) $ that corresponds to the policy (Assume $ γ=1 $)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Solution 3.

# %% [markdown]
# $$ v_π(s) = \sum_{s'∈S^+, r∈R} p(s', r | s, π(s))(r+γv_π(s')) $$

# %% [markdown]
# - (1) $ v_π (s_4) $
#     -  Route : $ s_4 $ → $ s_1 $ → $ s_2 $ → $ s_3 $ → $ s_6 $ → $ s_9 $
#     $$ v_π(s_4) = \sum_{s'∈S^+, r∈R} p(s', r | s_4, π(s_4))(r+γv_π(s')) $$
#     $$ (s_4 →  s_1) \; = p(s'=s_1, r=-1 | s_4, π(s_4))(r+γv_π(s')) = 1 * (-1 + 1*v_π(s_1))$$
#     $$ = -1 + 2 = 1 \; (∵ \; Question \; 3-(2) \; v_π(s_1) = 2) $$
#
# - (2) $ v_π (s_1 ) $
#     -  Route : $ s_1 $ → $ s_2 $ → $ s_3 $ → $ s_6 $ → $ s_9 $
#     $$ v_π(s_1) = \sum_{s'∈S^+, r∈R} p(s', r | s_1, π(s_1))(r+γv_π(s')) $$
#     $$ (1) (s_1 →  s_2) \; = p(s'=s_2, r=-1 | s_1, π(s_1))(r+γv_π(s')) = 1 * (-1 + 1*v_π(s_2))$$
#     $$ (2) \; (s_2 →  s_3) \; v_π(s_2) = p(s'=s_3, r=-1 | s_2, π(s_2))(r+γv_π(s')) = 1 * (-1 + 1*v_π(s_3)) $$
#     $$ (3) \; (s_3 →  s_6) \; v_π(s_3) = p(s'=s_6, r=-1 | s_3, π(s_3))(r+γv_π(s')) = 1 * (-1 + 1*v_π(s_6)) $$
#     $$ (4) \; (s_6 →  s_9) \; v_π(s_6) = p(s'=s_9, r=5 | s_6, π(s_6))(r+γv_π(s')) = 1 * (5 + 1*v_π(s_9)) $$
#     $$ (5) \; (s_9) \; v_π(s_9) = 0 \; (∵ \; terminal \; state) $$
#
#     $$ ∴ \; v_π (s_1) = -1 + v_π(s_2) = -1 + (-1 + v_π(s_3)) = -1 + (-1 + (-1 + v_π(s_6))) $$
#     $$ = -1 + (-1 + (-1 + (5 + v_π(s_9)))) = -1 + (-1 + (-1 + (5 + 0))) = 2 $$

# %% [markdown]
# ---

# %% [markdown]
# ### Problem 4. Mini Project: Dynamic Programming

# %% [markdown]
# There is a Jupyter Notebook and associated files ([Dropbox Link](https://www.dropbox.com/scl/fo/nn1yhk5tx7br7nhwfxbnj/h?rlkey=fcb7r6uue8g58r06s9v6lzzw7&dl=0)) for this problem.
# In the *Dynamic_Programming.ipynb* notebook, you will write your own implementations of many classical dynamic programming algorithms.

# %% [markdown]
# ### Solution 4.

# %% [markdown]
# [Error]
#
# ```
# !pip install -q matplotlib==2.2.2
# ```
#
#
# \>>>
#
# error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#
#   exit code: 1
