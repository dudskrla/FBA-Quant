# %% [markdown]
# # [HW5] FBA QUANT - ASSET PRICING

# %% [markdown]
# Kim Na Young (dudskrla09@gmail.com)

# %% [markdown]
# ---

# %% [markdown]
# # Assignment 1: Summary

# %% [markdown]
# ### Week 7. Liabilities and Long-term Debt

# %% [markdown]
# > Factors related to the time value of money
#
# - Inflation
# 	- prices tend to rise over time.
# - Interest
# 	- banks charge you money for having loans outstanding.
# 	- -> pay something back in the future > it is to borrow it today.
# - Risk
# 	- just having a dollar in your hand today is safer than getting a dollar
# 	- in the future, just because you don't know what's going to happen.
#
# > Future Value
# $$ FV = PV * (1+r) ^ n $$
# - Present Value (PV)
# - Future Value (FV)
# - Interest rate (r)
# - Number of periods (n)
#
# > Present Value
# $$ PV = \frac{FV}{(1+r) ^ n} $$
# - Present Value (PV)
# - Future Value (FV)
# - Interest rate (r)
# - Number of periods (n)
#
# > Present Value of annuities
# $$ PV = PMT * (\frac{1-\frac{1}{(1+r)^n}}{r}) $$
# - Present Value (PV)
# - Future Value (FV)
# - Interest rate (r)
# - Number of periods (n)
# - Periodic payment for an annuity (PMT)
#
# > Future Value of annuities
# $$ FV = PMT * (\frac{(1+r)^n -1}{r}) $$
# - Present Value (PV)
# - Future Value (FV)
# - Interest rate (r)
# - Number of periods (n)
# - Periodic payment for an annuity (PMT)
#
# > Different Compounding Periods
# - Annual compounding : n
# - Semi-annual compounding : 2*n
# - Monthly coumpounding : 12*n
# - Daily compounding : 365*n
#
# > Liabilities
# - Current Liabilities
# 	- initially booked at **nominal value**
# - Long-term Liabilities
# 	- initially booked at **present value**
#
# > Debts
# - Bank Loan
# 	- Principal : at **end** of loan
# 	- Interest : **periodic** interest payments
# - Mortgage
# 	- Principal : at **end** of loan
# 	- Interest : **periodic** interest payments
# - Corporate Bonds
# 	- Principal : lump sum at **maturity**
# 	- Interest : **periodic** cash flows (coupons)
#
# > Bonds Payable
# - Period
# 	- Coupon payments : semi-annual (every 6 months)
# 	- Face value : at maturity
# - Elements
# 	- Proceeds (PV)
# 	- Face Value (FV)
# 	- Effective market interest, yield to maturity (r)
# 	- Coupon rate
# 	- Coupon payment (PMT) = Face value * Coupon rate
# 	- Numbers of periods (n)
# - Proceeds
# 	$$ Price = Present \; value \; of \; FV + Present \; value \; of \; PMT $$
#
#
# > Discount and Premium Bonds
# - Discount Bonds
# 	- Price (PV) < Face value (FV)
# 	- Coupon rate < Current marktet rate → Investors pay less for bond
# - Premium Bonds
# 	- Price (PV) > Face value (FV)
# 	- Coupon rate > Current marktet rate → Investors pay more for bond
#
# > Retirement Before Maturity
# - If firms have excess cash or as part of refinancing activities, they retire bonds prior to maturity
# - Firms must buy the bonds back from investors at **current market prices**
#
#
# > Leases
# - Short-term Lease
# - Long-term Lease
# 	- Capital Lease
# 		- Record a Lease Asset and Lease Liability **on the balance sheet**
# 	- Operating Lease
# 		- **No** asset or liability **on the balance sheet** (**Off-balance sheet**)
# 		- Record Rent Expense **on the Income Statement**

# %% [markdown]
# ### Week8. Deferred Taxes

# %% [markdown]
# > Income Tax Expense VS. Income Tax Payable
# - Income Tax Expense
#     - based on pre-tax income computed using GAAP or IFRS
#     $$ Income \; Tax \; Expense = Pre-tax \; income \; (per \; GAAP \; rules) * Effective \; tax \; rate $$
#     $$ = Adjusted \; Pre-tax \; income * Statutory \; rate $$
# - Income Tax Payable
#     - based on taxable income using tax code rules
#     $$ Income \; Tax \; Payable = Taxable \; income \; (per \; IFS \; rules) * Statutory \; tax \; rate $$
#
# > Permanent Differences VS. Temporary Differences
# - Permanent Differences
#     - Revenues & Expenses : are never deductible for tax purposes
# - Temporary Differences
#     - Revenues & Expenses : recognized in a difference period for tax purposes
#
# > Pre-Tax Income VS. Taxable Income
# - Pre-Tax Income
#     - Earnings before taxes under GAAP
# - Taxable Income
#     - Earnings before taxes under tax rules
# - Adjusted Pre-Tax Income
#     - Pre-tax income adjusted for permanent tax differences (for financial reporting purposes)
#
# > Effective Tax Rate VS. Statutory Tax Rate
# - Effective Tax Rate
#     $$ Effective \; Tax \; Rate = \frac{Income \; Tax}{Pre-Tax \; Income}$$
# - Statutory Tax Rate
#     - Tax rate set by the government
#
# > Deferred Tax Liabilities
# - represents the obligation to make higher tax payments in the future
# - (Today) tax rules require bigger expenses or smaller revenues than GAAP
#     - Pre-tax income > Taxable income
#     - Income tax expense > Income tax payable
# - (Future) GAAP require bigger expenses or smaller revenues than tax rules
#     - Pre-tax income <> Taxable income
#     - Income tax expense < Income tax payable
#
# > Net Operating Losses (NOLs)
# - occurs in a year when taxable income is negative

# %% [markdown]
# ---

# %% [markdown]
# # Assignment 2: Making Problems

# %% [markdown]
# ## Problem 1.

# %% [markdown]
# A company issues a 5-year, 4% coupon bond with a face value of $100,000. The effective market interest rate at the time of issuance is 2%. What are the proceeds from issuing the bond?

# %% [markdown]
# ## Problem 2.

# %% [markdown]
# On 6/30/12, a company paid $96,000 to retire a bond before maturity. The company recorded a $6,000 gain as part of the transaction. Which of the following must be true regarding this transaction? (check all that apply)
#
#
# (1) The market interest rate had increased since the bond was issued
# (2) The market interest rate had decreased since the bond was issued
# (3) The company paid less than the current market value of the bond to retire it
# (4) The face value of the bond was $102,000
# (5) The face value of the bond was $96,000

# %% [markdown]
# ## Problem 3.

# %% [markdown]
# Which of the following changes would increase the present value of an annuity of future payments? (check all that apply)
#
# (1) Increase in the amount of the annuity payments
# (2) Decrease in the number of years over which the annuity payments are revceived
# (3) Decrease in the interest rate
# (4) Increase in the interest rate
# (5) Increase in the number of years over which the annuity payments are received

# %% [markdown]
# ## Solution 1.

# %% [markdown]
# - period (n) : 5
# - coupon rate (α) : 0.04
# - face value (F) : $100,000
# - effective market interest rate (r) : 0.02
#
# $$ Proceeds = PV \; of \; FV + PV \; of \; PMT $$
# $$ = \frac{F}{(1+ \frac{r}{2})^{2*n}} + \frac{F*\frac{α}{2}}{\frac{r}{2}}*(1-\frac{1}{(1+\frac{r}{2})^{2*n}}) $$
# $$ = \frac{\$100,000}{(1+ \frac{0.02}{2})^{2*5}} + \frac{\$100,000*\frac{0.04}{2}}{\frac{0.02}{2}}*(1-\frac{1}{(1+\frac{0.02}{2})^{2*5}}) $$
# $$ ≈ 109471.3045 $$

# %% [markdown]
# ## Solution 2.

# %% [markdown]
# **(1) The market interest rate had increased since the bond was issued**
#
# The only true statement is that the market interest rate had increased since the bond was issued.  Companies will always record a gain on retirement when the market rate increases since the bond was issued. The gain does not imply anything about the face value of the bond.  The company would have had to pay the current market value of the bond in order to retire it.

# %% [markdown]
# ## Solution 3.

# %% [markdown]
# **(1) Increase in the amount of the annuity payments**
# **(3) Decrease in the interest rate**
# **(5) Increase in the number of years over which the annuity payments are received**
#
# $$ PV = PMT * (\frac{1-\frac{1}{(1+r)^n}}{r}) $$
#
# Present value of an annuity is inversely related to the interest rate (r) and positively related to the number of periods (n) and the payment.  So a decrease in the interest rate would increase the PV.  An increase in the number of periods and the payment would also increase the PV.
#
# - (More) (3) Decrease in the interest rate
#
#     In the formula, the interest rate (r) appears in both the denominator and the numerator, but due to the influence of the squared (or exponential) terms at these two locations, changes in the magnitude of the interest rate (r) lead to differences in the result.

# %% [markdown]
# ---

# %% [markdown]
# # Assignment 3: Implementing the codes in the textbook

# %% [markdown]
# ### 1. Outlier detection using rolling statistics

# %% [markdown]
# Detect outliers based on **the rolling average** and **standard deviation**.

# %% [markdown]
# > Outlier
#
# Observations that are significantly different from the majority.
# We should identify and handle the outliers before creating any models.

# %% [markdown]
# ***[Code] Identifying the outliers as separate operations***

# %%
# 1. Import the libraries
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# 2. Download Tesla’s stock prices from 2019 to 2020 and calculate simple returns
df = yf.download("TSLA",
    start="2019-01-01",
    end="2020-12-31",
    progress=False)

df["rtn"] = df["Adj Close"].pct_change()
df = df[["rtn"]].copy()

# 3. Calculate the 21-day rolling mean and standard deviation
df_rolling = df[["rtn"]].rolling(window=21) \
                        .agg(["mean", "std"])
df_rolling.columns = df_rolling.columns.droplevel()

# 4. Join the rolling data back to the initial DataFrame
df = df.join(df_rolling)

# 5. Calculate the upper and lower thresholds
N_SIGMAS = 3
df["upper"] = df["mean"] + N_SIGMAS * df["std"]
df["lower"] = df["mean"] - N_SIGMAS * df["std"]

# 6. Identify the outliers using the previously calculated thresholds
df["outlier"] = (
    (df["rtn"] > df["upper"]) | (df["rtn"] < df["lower"])
)

# 7. Plot the returns together with the thresholds and mark the outliers
fig, ax = plt.subplots()
df[["rtn", "upper", "lower"]].plot(ax=ax)
ax.scatter(df.loc[df["outlier"]].index,
            df.loc[df["outlier"], "rtn"],
            color="black", label="outlier")
ax.set_title("Tesla's stock returns")
ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# > Analysis
#
# One thing to notice is that when there are two large (in absolute terms) returns in the vicinity of one another,
# the algorithm identifies **the first** one as an **outlier** and **the second one** as **a regular observation**.
#
# This might be due to the fact that **the first outlier** enters the rolling window and **affects the moving average/standard deviation**.

# %% [markdown]
# > Ghost Effect
#
# When a single outlier enters the rolling window,
# it inflates the values of the rolling statistics for as long as it remains in the rolling window.

# %% [markdown]
# ***[Code] Identifying the outliers as function***

# %%
def identify_outliers(df, column, window_size, n_sigmas):
    """
        Function for identifying outliers using rolling statistics
    """
    
    # 2. Download stock prices and calculate simple returns
    df = df[[column]].copy()
    
    # 3. Calculate the window_size-day rolling mean and standard deviation
    df_rolling = df.rolling(window=window_size) \
                    .agg(["mean", "std"])
    df_rolling.columns = df_rolling.columns.droplevel()
    
    # 4. Join the rolling data back to the initial DataFrame
    df = df.join(df_rolling)
    
    # 5. Calculate the upper and lower thresholds
    df["upper"] = df["mean"] + n_sigmas * df["std"]
    df["lower"] = df["mean"] - n_sigmas * df["std"]
    
    # 6. Identify the outliers using the previously calculated thresholds (return type: bool)
    return ((df[column] > df["upper"]) | (df[column] < df["lower"]))

# %% [markdown]
# > Winsorization
#
# It is based on **replacing outliers in data** to limit their effect on any potential calculations.
# ex. A 90% winsorization results in replacing *the top 5%* of values *with the 95th percentile*.
# ex. Similarly, *the bottom 5%* is replaced using the value of *the 5th percentile*.
# We can find the corresponding winsorize function in the scipy library.

# %% [markdown]
# #### 2. Outlier detection with the Hampel filter

# %% [markdown]
# ***[Code] Apply the filter to the adjusted close prices***

# %%
# !pip install sktime

# 1. Import the libraries
import yfinance as yf
from sktime.transformations.series.outlier_detection import HampelFilter

# 2. Download Tesla’s stock prices from the years 2019 to 2020 and calculate simple returns
df = yf.download("TSLA",
        start="2019-01-01",
        end="2020-12-31",
        progress=False)
df["rtn"] = df["Adj Close"].pct_change()

# 3. Instantiate the HampelFilter class and use it for detecting the outliers
hampel_detector = HampelFilter(window_length=10, 
                                return_bool=True)
df["outlier"] = hampel_detector.fit_transform(df["Adj Close"])

# 4. Plot Tesla’s stock price and mark the outliers
fig, ax = plt.subplots()
df[["Adj Close"]].plot(ax=ax)
ax.scatter(df.loc[df["outlier"]].index,
                df.loc[df["outlier"], "Adj Close"],
                color="black", label="outlier")
ax.set_title("Tesla's stock price")
ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# ***[Code] Apply the filter to the returns***

# %%
# 1. Identify the outliers among the stock returns
df["outlier_rtn"] = hampel_detector.fit_transform(df["rtn"])

# 2. Plot Tesla’s daily returns and mark the outliers
fig, ax = plt.subplots()
df[["rtn"]].plot(ax=ax)
ax.scatter(df.loc[df["outlier_rtn"]].index,
            df.loc[df["outlier_rtn"], "rtn"],
            color="black", label="outlier")
ax.set_title("Tesla's stock returns")
ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.show()

# %%
# 3. Investigate the overlap in outliers identified for the prices and returns
df.query("outlier == True and outlier_rtn == True") 

# There is only a single date that was identified as an outlier based on both prices and returns.
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2019-09-24  16.101334  16.132668  14.840667  14.880667  14.880667  193372500
#
#                  rtn  outlier  outlier_rtn
# Date
# 2019-09-24 -0.074701     True         True

# %% [markdown]
# > Anomaly/outlier detection references
#
# - https://github.com/datamllab/tods
# - https://github.com/zillow/luminaire/
# - https://github.com/signals-dev/Orion
# - https://pycaret.org/anomaly-detection/
# - https://github.com/twitter/AnomalyDetection—this : R package (created by Twitter) was ported to Python
# - Hampel F. R. 1974. “The influence curve and its role in robust estimation.” Journal of the American Statistical Association, 69: 382-393—a paper introducing the Hampel filter
# - https://www.sktime.org/en/latest/index.html—documentation of sktime

# %% [markdown]
# ### 3. Detecting changepoints in time series

# %% [markdown]
# > Changepoint
#
# **A changepoint** can be defined as a point in time when **the probability distribution** of a process or time series **changes**.
#     ex. there is a change to the mean in the series.
# We will use **the CUSUM (cumulative sum) method** to detect shifts of the means in a time series.
#
#
# ***Algorithm***
# - **(1) Find the changepoint**
#     1) **Initialize** a changepoint in the middle of the given time series.
#     2) The CUSUM approach is carried out based on the selected point.
#     3) The following changepoint is located where the previous CUSUM time series is **either maximized or minimized** (depending on the direction of the changepoint we want to locate).
#     4) We continue this process until a stable changepoint is located or we exceed the maximum number of iterations.
# - **(2) Test its statistical significance**
#     **A log-likelihood ratio test** is used to **test** if the mean of the given time series **changes at the identified changepoint**. By default, the changepoints are only reported if the null hypothesis is rejected. The null hypothesis states that there
# is no change in the mean of the series.

# %% [markdown]
# ***[Code] Apply the CUSUM algorithm to identify changepoints***

# %%
# !pip install kats

# 1. Import the libraries
import yfinance as yf
from kats.detectors.cusum_detection import CUSUMDetector
from kats.consts import TimeSeriesData

# 2. Download Apple’s stock price from 2020
df = yf.download("AAPL",
        start="2020-01-01",
        end="2020-12-31",
        progress=False)

# 3. Keep only the adjusted close price, reset the index, and rename the columns
df = df[["Adj Close"]].reset_index(drop=False)
df.columns = ["time", "price"]

# 4. Convert the DataFrame into a TimeSeriesData object
tsd = TimeSeriesData(df)

# 5. Instantiate and run the changepoint detector
cusum_detector = CUSUMDetector(tsd)
change_points = cusum_detector.detector(
                    change_directions=["increase"] # only interested in increases
                )
cusum_detector.plot(change_points)
# Out:
# WARNING:root:No change points detected!
# <AxesSubplot:>

# %%
# 6. Investigate the detected changepoint in more detail
point, meta = change_points[0], _
point
# Out:
# CUSUMChangePoint(start_time: 2020-07-30 00:00:00, end_time: 2020-07-30 00:00:00, confidence: 1.0, direction: increase, index: 145, delta: 39.716699205833876, regression_detected: True, stable_changepoint: True, mu0: 76.66418543253859, mu1: 116.38088463837246, llr: 451.89565512412906, llr_int: inf, p_value: 0.0, p_value_int: nan)

# %% [markdown]
# ***[Code] Restrict the detection window***

# %%
change_points = cusum_detector.detector(change_directions=["increase"],
                                        interest_window=[200, 250])
cusum_detector.plot(change_points)
# Out:
# WARNING:root:No change points detected!
# <AxesSubplot:>

# %% [markdown]
# > RobustStatDetector
#
# It smoothens the data using **moving averages** before identifying the points of interest.
# Another interesting feature of the algorithm is that it can **detect multiple changepoints in a single run.**

# %% [markdown]
# ***[Code] Using different changepoint detection algorithms: RobustStatDetector***

# %%
from kats.detectors.robust_stat_detection import RobustStatDetector

robust_detector = RobustStatDetector(tsd)
change_points = robust_detector.detector()
robust_detector.plot(change_points)
# Out:
# WARNING:root:No change points detected!
# <AxesSubplot:>

# %% [markdown]
# ### 4. Detecting trends in time series

# %%
# 1. Import the libraries
import yfinance as yf
from kats.consts import TimeSeriesData
from kats.detectors.trend_mk import MKDetector

# 2. Download NVIDIA’s stock prices from 2020
df = yf.download("NVDA",
                    start="2020-01-01",
                    end="2020-12-31",
                    progress=False)

# 3. Keep only the adjusted close price, reset the index, and rename the columns
df = df[["Adj Close"]].reset_index(drop=False)
df.columns = ["time", "price"]

# 4. Convert the DataFrame into a TimeSeriesData object
tsd = TimeSeriesData(df)

# 5. Instantiate and run the trend detector
trend_detector = MKDetector(tsd, threshold=0.9)
time_points = trend_detector.detector(
                                        direction="up", 
                                        window_size=30
                                    )   

# 6. Plot the detected time points
trend_detector.plot(time_points)
# Out:
# WARNING:root:No trend detected!
# <AxesSubplot:>

# %% [markdown]
# ### 5. Detecting patterns in a time series using the Hurst exponent

# %%
# 1. Import the libraries
import yfinance as yf
import numpy as np
import pandas as pd

# 2. Download S&P 500’s historical prices from the years 2000 to 2019
df = yf.download("^GSPC",
                    start="2000-01-01",
                    end="2019-12-31",
                    progress=False)
df["Adj Close"].plot(title="S&P 500 (years 2000-2019)")

# 3. Define a function calculating the Hurst exponent
def get_hurst_exponent(ts, max_lag=20):
    """
        Returns the Hurst Exponent of the time series
    """
    
    lags = range(2, max_lag)
    tau = [np.std(np.subtract(ts[lag:], ts[:-lag])) for lag in lags]
    hurst_exp = np.polyfit(np.log(lags), np.log(tau), 1)[0]
    return hurst_exp

# 4. Calculate the values of the Hurst exponent using different values for the max_lag parameter
for lag in [20, 100, 250, 500, 1000]:
    hurst_exp = get_hurst_exponent(df["Adj Close"].values, lag)
    print(f"Hurst exponent with {lag} lags: {hurst_exp:.4f}")
    
# 5. Narrow down the data to the years 2005 to 2007 and calculate the exponents one more time
shorter_series = df.loc["2005":"2007", "Adj Close"].values
for lag in [20, 100, 250, 500]:
    hurst_exp = get_hurst_exponent(shorter_series, lag)
    print(f"Hurst exponent with {lag} lags: {hurst_exp:.4f}")
# Out:
# Hurst exponent with 20 lags: 0.4481
# Hurst exponent with 100 lags: 0.4513
# Hurst exponent with 250 lags: 0.4918
# Hurst exponent with 500 lags: 0.5265
# Hurst exponent with 1000 lags: 0.5178
# Hurst exponent with 20 lags: 0.3989
# Hurst exponent with 100 lags: 0.3215
# Hurst exponent with 250 lags: 0.2507
# Hurst exponent with 500 lags: 0.1258

# %% [markdown]
# ### 6. Investigating stylized facts of asset returns

# %%
# 1. Import the required libraries
import pandas as pd
import numpy as np
import yfinance as yf
import seaborn as sns
import scipy.stats as scs
import statsmodels.api as sm
import statsmodels.tsa.api as smt

# 2. Download the S&P 500 data and calculate the returns
df = yf.download("^GSPC", 
                    start="2000-01-01", 
                    end="2020-12-31",
                    progress=False)
df = df[["Adj Close"]].rename(
                        columns={"Adj Close": "adj_close"}
                        )
df["log_rtn"] = np.log(df["adj_close"]/df["adj_close"].shift(1))
df = df[["adj_close", "log_rtn"]].dropna()

# %% [markdown]
# ***Fact 1: Non-Gaussian distribution of returns***

# %%
# 1. Calculate the Normal probability density function (PDF) using the mean and standard deviation of the observed returns
r_range = np.linspace(min(df["log_rtn"]), 
                    max(df["log_rtn"]), 
                    num=1000)
mu = df["log_rtn"].mean()
sigma = df["log_rtn"].std()
norm_pdf = scs.norm.pdf(r_range, loc=mu, scale=sigma) 

# 2. Plot the histogram and the Q-Q plot
fig, ax = plt.subplots(1, 2, figsize=(16, 8))

# histogram
sns.distplot(df.log_rtn, kde=False, 
            norm_hist=True, ax=ax[0]) 
# sns.histplot(df.log_rtn, kde=False, ax=ax[0])
ax[0].set_title("Distribution of S&P 500 returns", 
 fontsize=16) 
ax[0].plot(r_range, norm_pdf, "g", lw=2, 
 label=f"N({mu:.2f}, {sigma**2:.4f})")
ax[0].legend(loc="upper left")

# Q-Q plot
qq = sm.qqplot(df.log_rtn.values, line="s", ax=ax[1])
ax[1].set_title("Q-Q plot", fontsize=16)
plt.show()

# %% [markdown]
# ***Fact 2: Volatility clustering***

# %%
(
 df["log_rtn"]
 .plot(title="Daily S&P 500 returns", figsize=(10, 6))
)
# Out:
# <AxesSubplot:title={'center':'Daily S&P 500 returns'}, xlabel='Date'>

# %% [markdown]
# ***Fact 3: Absence of autocorrelation in returns***

# %%
# 1. Define the parameters for creating the autocorrelation plots
N_LAGS = 50
SIGNIFICANCE_LEVEL = 0.05

# 2. Run the following code to create the autocorrelation function (ACF) plot of log returns
acf = smt.graphics.plot_acf(df["log_rtn"],
                            lags=N_LAGS,
                            alpha=SIGNIFICANCE_LEVEL)
plt.show()

# %% [markdown]
# ***Fact 4: Small and decreasing autocorrelation in squared/absolute returns***

# %%
fig, ax = plt.subplots(2, 1, figsize=(12, 10))
smt.graphics.plot_acf(df["log_rtn"]**2, lags=N_LAGS,
 alpha=SIGNIFICANCE_LEVEL, ax=ax[0])
ax[0].set(title="Autocorrelation Plots",
 ylabel="Squared Returns")
smt.graphics.plot_acf(np.abs(df["log_rtn"]), lags=N_LAGS,
 alpha=SIGNIFICANCE_LEVEL, ax=ax[1])
ax[1].set(ylabel="Absolute Returns",
 xlabel="Lag")
plt.show()

# %% [markdown]
# ***Fact 5: Leverage effect***

# %%
# 1. Calculate volatility measures as moving standard deviations
df["rolling_std_252"] = df[["log_rtn"]].rolling(window=252).std()
df["rolling_std_21"] = df[["log_rtn"]].rolling(window=21).std()

# 2. Plot all the series
fig, ax = plt.subplots(3, 1, figsize=(18, 15),
 sharex=True)
df["adj_close"].plot(ax=ax[0])
ax[0].set(title="S&P 500 time series",
 ylabel="Price ($)")
df["log_rtn"].plot(ax=ax[1])
ax[1].set(ylabel="Log returns")
df["rolling_std_252"].plot(ax=ax[2], color="r",
 label="Rolling Volatility 252d")
df["rolling_std_21"].plot(ax=ax[2], color="g",
 label="Rolling Volatility 21d")
ax[2].set(ylabel="Moving Volatility",
 xlabel="Date")
ax[2].legend()
plt.show()

# %% [markdown]
# ---
#
# ### Errors related to installing Kats library

# %%
# 0) Python version error

# [Error message]
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   Ignoring numpy: markers 'python_version == "3.6"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7"' don't match your environment

# [Error fixing-Insert this command in Anaconda Prompt]
#   conda create -n fba python=3.7

# %%
# 1) Module not found error related to convertdate

# [Error message]
#   ModuleNotFoundError: No module named 'convertdate'

# [Error fixing-Insert this command in Anaconda Prompt]
#   pip install convertdate

# %%
# 2) Type error related to holidays

# [Error message]
#   TypeError: This is a python-holidays entity loader class. 
#   For entity inheritance purposes please import a class you want to derive from directly: 
#   e.g., `from holidays.countries import Entity` or `from holidays.financial import Entity`.

# [Error fixing - Fix the codes in the python file]
#   Change codes in the site-packages\holidays\registry.py file in conda environment
#   1. Comment these codes (lines 180 ~ 187).
#       """ # USER
#       if args:
#           raise TypeError(
#               "This is a python-holidays entity loader class. "
#               "For entity inheritance purposes please import a class you "
#               "want to derive from directly: e.g., "
#               "`from holidays.countries import Entity` or "
#               "`from holidays.financial import Entity`."
#           )
#       """
#   2. Change this code
#       Before) super().__init__(*args, **kwargs)
#       After) super().__init__() 

# Ref. https://github.com/facebookresearch/Kats/issues/308

# %%
# 3) Import error related to pystan

# [Error message]
#   ImportError: DLL load failed: %1은(는) 올바른 Win32 응용 프로그램이 아닙니다.

# [Error fixing - Insert this command in Anaconda Prompt]
# conda install libpython m2w64-toolchain -c msys2

# Ref. https://stackoverflow.com/questions/60388880/import-pystan-api-failedimporterror-dll-load-failed-the-specified-module-cou

# %%
# 4) Attribute error related to packaging

# [Error message]
#   AttributeError: module 'packaging.version' has no attribute 'LegacyVersion'

# [Error fixing - Insert this command in Anaconda Prompt]
#   conda install packaging=21.3

# %%
# 5) More

# [Insert these command in Anaconda Prompt]
#   pip install pystan==2.17.1
#   pip install fbprophet==0.6
#   pip install kats
